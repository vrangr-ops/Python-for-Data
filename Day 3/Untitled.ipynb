# %%
print ('hello world')
# Out:
# hello world

# %%
list_data = [1,2,3,4,5]

# %%
array_data = np.array(list_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 array_data = np.array(list_data)
#
# NameError: name 'np' is not defined

# %%
print('NumPy array:' , array_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print('NumPy array:' , array_data)
#
# NameError: name 'array_data' is not defined
